# %% [markdown]
# # **Staging Areas**

# %%
import pandas as pd
import numpy as np
import sqlalchemy

# %%
cust= pd.read_csv('CUST_AZ12.csv')
cust
# Out:
#                  CID       BDATE     GEN
# 0      NASAW00011000  1971-10-06    Male
# 1      NASAW00011001  1976-05-10    Male
# 2      NASAW00011002  1971-02-09    Male
# 3      NASAW00011003  1973-08-14  Female
# 4      NASAW00011004  1979-08-05  Female
# ...              ...         ...     ...
# 18479     AW00029479  1969-06-30     NaN
# 18480     AW00029480  1977-05-06     NaN
# 18481     AW00029481  1965-07-04     NaN
# 18482     AW00029482  1964-09-01     NaN
# 18483     AW00029483  1965-06-06     NaN
#
# [18484 rows x 3 columns]

# %%
cust['CID'] = cust['CID'].str.extract('(\d+)').astype(int)
cust
# Out:
#          CID       BDATE     GEN
# 0      11000  1971-10-06    Male
# 1      11001  1976-05-10    Male
# 2      11002  1971-02-09    Male
# 3      11003  1973-08-14  Female
# 4      11004  1979-08-05  Female
# ...      ...         ...     ...
# 18479  29479  1969-06-30     NaN
# 18480  29480  1977-05-06     NaN
# 18481  29481  1965-07-04     NaN
# 18482  29482  1964-09-01     NaN
# 18483  29483  1965-06-06     NaN
#
# [18484 rows x 3 columns]

# %%
cust_info= pd.read_csv('cust_info.csv')
cust_info
# Out:
#         cst_id     cst_key cst_firstname cst_lastname cst_marital_status  \
# 0      11000.0  AW00011000           Jon        Yang                   M
# 1      11001.0  AW00011001        Eugene      Huang                    S
# 2      11002.0  AW00011002         Ruben       Torres                  M
# 3      11003.0  AW00011003       Christy          Zhu                  S
# 4      11004.0  AW00011004     Elizabeth      Johnson                  S
# ...        ...         ...           ...          ...                ...
# 18489  29482.0  AW00029482       Clayton        Zhang                  M
# 18490  29483.0  AW00029483           NaN      Navarro                NaN
# 18491  29483.0  AW00029483          Marc      Navarro                  M
# 18492      NaN    13451235           NaN          NaN                NaN
# 18493      NaN      A01Ass           NaN          NaN                NaN
#
#       cst_gndr cst_create_date
# 0            M      2025-10-06
# 1            M      2025-10-06
# 2            M      2025-10-06
# 3            F      2025-10-06
# 4            F      2025-10-06
# ...        ...             ...
# 18489      NaN      2026-01-25
# 18490      NaN      2026-01-25
# 18491      NaN      2026-01-27
# 18492      NaN             NaN
# 18493      NaN             NaN
#
# [18494 rows x 7 columns]

# %%
cust_info.rename(columns={'cst_key': 'CID'}, inplace=True)
cust_info['CID'] = cust_info['CID'].str.extract('(\d+)').astype(int)
cust_info
# Out:
#         cst_id       CID cst_firstname cst_lastname cst_marital_status  \
# 0      11000.0     11000           Jon        Yang                   M
# 1      11001.0     11001        Eugene      Huang                    S
# 2      11002.0     11002         Ruben       Torres                  M
# 3      11003.0     11003       Christy          Zhu                  S
# 4      11004.0     11004     Elizabeth      Johnson                  S
# ...        ...       ...           ...          ...                ...
# 18489  29482.0     29482       Clayton        Zhang                  M
# 18490  29483.0     29483           NaN      Navarro                NaN
# 18491  29483.0     29483          Marc      Navarro                  M
# 18492      NaN  13451235           NaN          NaN                NaN
# 18493      NaN         1           NaN          NaN                NaN
#
#       cst_gndr cst_create_date
# 0            M      2025-10-06
# 1            M      2025-10-06
# 2            M      2025-10-06
# 3            F      2025-10-06
# 4            F      2025-10-06
# ...        ...             ...
# 18489      NaN      2026-01-25
# 18490      NaN      2026-01-25
# 18491      NaN      2026-01-27
# 18492      NaN             NaN
# 18493      NaN             NaN
#
# [18494 rows x 7 columns]

# %%
loc = pd.read_csv('LOC_A101.csv')
loc
# Out:
#                CID           CNTRY
# 0      AW-00011000       Australia
# 1      AW-00011001       Australia
# 2      AW-00011002       Australia
# 3      AW-00011003       Australia
# 4      AW-00011004       Australia
# ...            ...             ...
# 18479  AW-00029479          France
# 18480  AW-00029480  United Kingdom
# 18481  AW-00029481         Germany
# 18482  AW-00029482          France
# 18483  AW-00029483          France
#
# [18484 rows x 2 columns]

# %%
loc['CID'] = loc['CID'].str.replace('-', '')
loc['CID'] = loc['CID'].str.extract('(\d+)').astype(int)
loc
# Out:
#          CID           CNTRY
# 0      11000       Australia
# 1      11001       Australia
# 2      11002       Australia
# 3      11003       Australia
# 4      11004       Australia
# ...      ...             ...
# 18479  29479          France
# 18480  29480  United Kingdom
# 18481  29481         Germany
# 18482  29482          France
# 18483  29483          France
#
# [18484 rows x 2 columns]

# %%
merged_df = pd.merge(cust, cust_info, on='CID', how='inner')
merged_df
# Out:
#          CID       BDATE     GEN   cst_id cst_firstname cst_lastname  \
# 0      11000  1971-10-06    Male  11000.0           Jon        Yang
# 1      11001  1976-05-10    Male  11001.0        Eugene      Huang
# 2      11002  1971-02-09    Male  11002.0         Ruben       Torres
# 3      11003  1973-08-14  Female  11003.0       Christy          Zhu
# 4      11004  1979-08-05  Female  11004.0     Elizabeth      Johnson
# ...      ...         ...     ...      ...           ...          ...
# 18485  29480  1977-05-06     NaN  29480.0          Nina         Raji
# 18486  29481  1965-07-04     NaN  29481.0          Ivan         Suri
# 18487  29482  1964-09-01     NaN  29482.0       Clayton        Zhang
# 18488  29483  1965-06-06     NaN  29483.0           NaN      Navarro
# 18489  29483  1965-06-06     NaN  29483.0          Marc      Navarro
#
#       cst_marital_status cst_gndr cst_create_date
# 0                      M        M      2025-10-06
# 1                      S        M      2025-10-06
# 2                      M        M      2025-10-06
# 3                      S        F      2025-10-06
# 4                      S        F      2025-10-06
# ...                  ...      ...             ...
# 18485                  S      NaN      2026-01-25
# 18486                  S      NaN      2026-01-25
# 18487                  M      NaN      2026-01-25
# 18488                NaN      NaN      2026-01-25
# 18489                  M      NaN      2026-01-27
#
# [18490 rows x 9 columns]

# %%
cust_df = pd.merge(merged_df, loc, on='CID', how='inner')
cust_df
# Out:
#          CID       BDATE     GEN   cst_id cst_firstname cst_lastname  \
# 0      11000  1971-10-06    Male  11000.0           Jon        Yang
# 1      11001  1976-05-10    Male  11001.0        Eugene      Huang
# 2      11002  1971-02-09    Male  11002.0         Ruben       Torres
# 3      11003  1973-08-14  Female  11003.0       Christy          Zhu
# 4      11004  1979-08-05  Female  11004.0     Elizabeth      Johnson
# ...      ...         ...     ...      ...           ...          ...
# 18485  29480  1977-05-06     NaN  29480.0          Nina         Raji
# 18486  29481  1965-07-04     NaN  29481.0          Ivan         Suri
# 18487  29482  1964-09-01     NaN  29482.0       Clayton        Zhang
# 18488  29483  1965-06-06     NaN  29483.0           NaN      Navarro
# 18489  29483  1965-06-06     NaN  29483.0          Marc      Navarro
#
#       cst_marital_status cst_gndr cst_create_date           CNTRY
# 0                      M        M      2025-10-06       Australia
# 1                      S        M      2025-10-06       Australia
# 2                      M        M      2025-10-06       Australia
# 3                      S        F      2025-10-06       Australia
# 4                      S        F      2025-10-06       Australia
# ...                  ...      ...             ...             ...
# 18485                  S      NaN      2026-01-25  United Kingdom
# 18486                  S      NaN      2026-01-25         Germany
# 18487                  M      NaN      2026-01-25          France
# 18488                NaN      NaN      2026-01-25          France
# 18489                  M      NaN      2026-01-27          France
#
# [18490 rows x 10 columns]

# %%
prd= pd.read_csv('prd_info.csv')
prd
# Out:
#      prd_id           prd_key                     prd_nm  prd_cost prd_line  \
# 0       210  CO-RF-FR-R92B-58  HL Road Frame - Black- 58       NaN       R
# 1       211  CO-RF-FR-R92R-58    HL Road Frame - Red- 58       NaN       R
# 2       212   AC-HE-HL-U509-R      Sport-100 Helmet- Red      12.0       S
# 3       213   AC-HE-HL-U509-R      Sport-100 Helmet- Red      14.0       S
# 4       214   AC-HE-HL-U509-R      Sport-100 Helmet- Red      13.0       S
# ..      ...               ...                        ...       ...      ...
# 392     602     CO-BB-BB-8107          ML Bottom Bracket      45.0      NaN
# 393     603     CO-BB-BB-9108          HL Bottom Bracket      54.0      NaN
# 394     604  BI-RB-BK-R19B-44         Road-750 Black- 44     344.0       R
# 395     605  BI-RB-BK-R19B-48         Road-750 Black- 48     344.0       R
# 396     606  BI-RB-BK-R19B-52         Road-750 Black- 52     344.0       R
#
#     prd_start_dt  prd_end_dt
# 0     2003-07-01         NaN
# 1     2003-07-01         NaN
# 2     2011-07-01  2007-12-28
# 3     2012-07-01  2008-12-27
# 4     2013-07-01         NaN
# ..           ...         ...
# 392   2013-07-01         NaN
# 393   2013-07-01         NaN
# 394   2013-07-01         NaN
# 395   2013-07-01         NaN
# 396   2013-07-01         NaN
#
# [397 rows x 7 columns]

# %%
prd['ID'] = prd['prd_key'].str[:5].str.replace('-', '_')
prd
# Out:
#      prd_id           prd_key                     prd_nm  prd_cost prd_line  \
# 0       210  CO-RF-FR-R92B-58  HL Road Frame - Black- 58       NaN       R
# 1       211  CO-RF-FR-R92R-58    HL Road Frame - Red- 58       NaN       R
# 2       212   AC-HE-HL-U509-R      Sport-100 Helmet- Red      12.0       S
# 3       213   AC-HE-HL-U509-R      Sport-100 Helmet- Red      14.0       S
# 4       214   AC-HE-HL-U509-R      Sport-100 Helmet- Red      13.0       S
# ..      ...               ...                        ...       ...      ...
# 392     602     CO-BB-BB-8107          ML Bottom Bracket      45.0      NaN
# 393     603     CO-BB-BB-9108          HL Bottom Bracket      54.0      NaN
# 394     604  BI-RB-BK-R19B-44         Road-750 Black- 44     344.0       R
# 395     605  BI-RB-BK-R19B-48         Road-750 Black- 48     344.0       R
# 396     606  BI-RB-BK-R19B-52         Road-750 Black- 52     344.0       R
#
#     prd_start_dt  prd_end_dt     ID
# 0     2003-07-01         NaN  CO_RF
# 1     2003-07-01         NaN  CO_RF
# 2     2011-07-01  2007-12-28  AC_HE
# 3     2012-07-01  2008-12-27  AC_HE
# 4     2013-07-01         NaN  AC_HE
# ..           ...         ...    ...
# 392   2013-07-01         NaN  CO_BB
# 393   2013-07-01         NaN  CO_BB
# 394   2013-07-01         NaN  BI_RB
# 395   2013-07-01         NaN  BI_RB
# 396   2013-07-01         NaN  BI_RB
#
# [397 rows x 8 columns]

# %%
cat= pd.read_csv('PX_CAT_G1V2.csv')
cat
# Out:
#        ID          CAT             SUBCAT MAINTENANCE
# 0   AC_BR  Accessories         Bike Racks         Yes
# 1   AC_BS  Accessories        Bike Stands          No
# 2   AC_BC  Accessories  Bottles and Cages          No
# 3   AC_CL  Accessories           Cleaners         Yes
# 4   AC_FE  Accessories            Fenders          No
# 5   AC_HE  Accessories            Helmets         Yes
# 6   AC_HP  Accessories    Hydration Packs          No
# 7   AC_LI  Accessories             Lights         Yes
# 8   AC_LO  Accessories              Locks         Yes
# 9   AC_PA  Accessories           Panniers          No
# 10  AC_PU  Accessories              Pumps         Yes
# 11  AC_TT  Accessories    Tires and Tubes         Yes
# 12  BI_MB        Bikes     Mountain Bikes         Yes
# 13  BI_RB        Bikes         Road Bikes         Yes
# 14  BI_TB        Bikes      Touring Bikes         Yes
# 15  CL_BS     Clothing         Bib-Shorts          No
# 16  CL_CA     Clothing               Caps          No
# 17  CL_GL     Clothing             Gloves          No
# 18  CL_JE     Clothing            Jerseys          No
# 19  CL_SH     Clothing             Shorts          No
# 20  CL_SO     Clothing              Socks          No
# 21  CL_TI     Clothing             Tights          No
# 22  CL_VE     Clothing              Vests          No
# 23  CO_BB   Components    Bottom Brackets         Yes
# 24  CO_BR   Components             Brakes         Yes
# 25  CO_CH   Components             Chains         Yes
# 26  CO_CS   Components          Cranksets         Yes
# 27  CO_DE   Components        Derailleurs         Yes
# 28  CO_FO   Components              Forks         Yes
# 29  CO_HB   Components         Handlebars          No
# 30  CO_HS   Components           Headsets          No
# 31  CO_MF   Components    Mountain Frames         Yes
# 32  CO_PD   Components             Pedals          No
# 33  CO_RF   Components        Road Frames         Yes
# 34  CO_SA   Components            Saddles          No
# 35  CO_TF   Components     Touring Frames         Yes
# 36  CO_WH   Components             Wheels         Yes

# %%
prd_df = pd.merge(prd, cat, on='ID', how='left')
prd_df
# Out:
#      prd_id           prd_key                     prd_nm  prd_cost prd_line  \
# 0       210  CO-RF-FR-R92B-58  HL Road Frame - Black- 58       NaN       R
# 1       211  CO-RF-FR-R92R-58    HL Road Frame - Red- 58       NaN       R
# 2       212   AC-HE-HL-U509-R      Sport-100 Helmet- Red      12.0       S
# 3       213   AC-HE-HL-U509-R      Sport-100 Helmet- Red      14.0       S
# 4       214   AC-HE-HL-U509-R      Sport-100 Helmet- Red      13.0       S
# ..      ...               ...                        ...       ...      ...
# 392     602     CO-BB-BB-8107          ML Bottom Bracket      45.0      NaN
# 393     603     CO-BB-BB-9108          HL Bottom Bracket      54.0      NaN
# 394     604  BI-RB-BK-R19B-44         Road-750 Black- 44     344.0       R
# 395     605  BI-RB-BK-R19B-48         Road-750 Black- 48     344.0       R
# 396     606  BI-RB-BK-R19B-52         Road-750 Black- 52     344.0       R
#
#     prd_start_dt  prd_end_dt     ID          CAT           SUBCAT MAINTENANCE
# 0     2003-07-01         NaN  CO_RF   Components      Road Frames         Yes
# 1     2003-07-01         NaN  CO_RF   Components      Road Frames         Yes
# 2     2011-07-01  2007-12-28  AC_HE  Accessories          Helmets         Yes
# 3     2012-07-01  2008-12-27  AC_HE  Accessories          Helmets         Yes
# 4     2013-07-01         NaN  AC_HE  Accessories          Helmets         Yes
# ..           ...         ...    ...          ...              ...         ...
# 392   2013-07-01         NaN  CO_BB   Components  Bottom Brackets         Yes
# 393   2013-07-01         NaN  CO_BB   Components  Bottom Brackets         Yes
# 394   2013-07-01         NaN  BI_RB        Bikes       Road Bikes         Yes
# 395   2013-07-01         NaN  BI_RB        Bikes       Road Bikes         Yes
# 396   2013-07-01         NaN  BI_RB        Bikes       Road Bikes         Yes
#
# [397 rows x 11 columns]

# %%
prd_df['prd_key'] = prd_df['prd_key'].str[6:]
prd_df
# Out:
#      prd_id     prd_key                     prd_nm  prd_cost prd_line  \
# 0       210  FR-R92B-58  HL Road Frame - Black- 58       NaN       R
# 1       211  FR-R92R-58    HL Road Frame - Red- 58       NaN       R
# 2       212   HL-U509-R      Sport-100 Helmet- Red      12.0       S
# 3       213   HL-U509-R      Sport-100 Helmet- Red      14.0       S
# 4       214   HL-U509-R      Sport-100 Helmet- Red      13.0       S
# ..      ...         ...                        ...       ...      ...
# 392     602     BB-8107          ML Bottom Bracket      45.0      NaN
# 393     603     BB-9108          HL Bottom Bracket      54.0      NaN
# 394     604  BK-R19B-44         Road-750 Black- 44     344.0       R
# 395     605  BK-R19B-48         Road-750 Black- 48     344.0       R
# 396     606  BK-R19B-52         Road-750 Black- 52     344.0       R
#
#     prd_start_dt  prd_end_dt     ID          CAT           SUBCAT MAINTENANCE
# 0     2003-07-01         NaN  CO_RF   Components      Road Frames         Yes
# 1     2003-07-01         NaN  CO_RF   Components      Road Frames         Yes
# 2     2011-07-01  2007-12-28  AC_HE  Accessories          Helmets         Yes
# 3     2012-07-01  2008-12-27  AC_HE  Accessories          Helmets         Yes
# 4     2013-07-01         NaN  AC_HE  Accessories          Helmets         Yes
# ..           ...         ...    ...          ...              ...         ...
# 392   2013-07-01         NaN  CO_BB   Components  Bottom Brackets         Yes
# 393   2013-07-01         NaN  CO_BB   Components  Bottom Brackets         Yes
# 394   2013-07-01         NaN  BI_RB        Bikes       Road Bikes         Yes
# 395   2013-07-01         NaN  BI_RB        Bikes       Road Bikes         Yes
# 396   2013-07-01         NaN  BI_RB        Bikes       Road Bikes         Yes
#
# [397 rows x 11 columns]

# %%
sales = pd.read_csv('sales_details.csv')
sales
# Out:
#       sls_ord_num sls_prd_key  sls_cust_id  sls_order_dt  sls_ship_dt  \
# 0         SO43697  BK-R93R-62        21768      20101229     20110105
# 1         SO43698  BK-M82S-44        28389      20101229     20110105
# 2         SO43699  BK-M82S-44        25863      20101229     20110105
# 3         SO43700  BK-R50B-62        14501      20101229     20110105
# 4         SO43701  BK-M82S-44        11003      20101229     20110105
# ...           ...         ...          ...           ...          ...
# 60393     SO75122     FE-6654        15868      20140128     20140204
# 60394     SO75122     CA-1098        15868      20140128     20140204
# 60395     SO75123     FE-6654        18759      20140128     20140204
# 60396     SO75123     ST-1401        18759      20140128     20140204
# 60397     SO75123     CA-1098        18759      20140128     20140204
#
#        sls_due_dt  sls_sales  sls_quantity  sls_price
# 0        20110110     3578.0             1     3578.0
# 1        20110110     3400.0             1     3400.0
# 2        20110110     3400.0             1     3400.0
# 3        20110110      699.0             1      699.0
# 4        20110110     3400.0             1     3400.0
# ...           ...        ...           ...        ...
# 60393    20140209       22.0             1       22.0
# 60394    20140209        9.0             1        9.0
# 60395    20140209       22.0             1       22.0
# 60396    20140209      159.0             1      159.0
# 60397    20140209        9.0             1        9.0
#
# [60398 rows x 9 columns]

# %%
sales.rename(columns={'sls_prd_key': 'prd_key', 'sls_cust_id': 'CID'}, inplace=True)
sales
# Out:
#       sls_ord_num     prd_key    CID  sls_order_dt  sls_ship_dt  sls_due_dt  \
# 0         SO43697  BK-R93R-62  21768      20101229     20110105    20110110
# 1         SO43698  BK-M82S-44  28389      20101229     20110105    20110110
# 2         SO43699  BK-M82S-44  25863      20101229     20110105    20110110
# 3         SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# 4         SO43701  BK-M82S-44  11003      20101229     20110105    20110110
# ...           ...         ...    ...           ...          ...         ...
# 60393     SO75122     FE-6654  15868      20140128     20140204    20140209
# 60394     SO75122     CA-1098  15868      20140128     20140204    20140209
# 60395     SO75123     FE-6654  18759      20140128     20140204    20140209
# 60396     SO75123     ST-1401  18759      20140128     20140204    20140209
# 60397     SO75123     CA-1098  18759      20140128     20140204    20140209
#
#        sls_sales  sls_quantity  sls_price
# 0         3578.0             1     3578.0
# 1         3400.0             1     3400.0
# 2         3400.0             1     3400.0
# 3          699.0             1      699.0
# 4         3400.0             1     3400.0
# ...          ...           ...        ...
# 60393       22.0             1       22.0
# 60394        9.0             1        9.0
# 60395       22.0             1       22.0
# 60396      159.0             1      159.0
# 60397        9.0             1        9.0
#
# [60398 rows x 9 columns]

# %%
sales_df = sales.merge(cust_df, how='left', left_on='CID', right_on='CID', suffixes=('', '_cust'))
sales_df
# Out:
#       sls_ord_num     prd_key    CID  sls_order_dt  sls_ship_dt  sls_due_dt  \
# 0         SO43697  BK-R93R-62  21768      20101229     20110105    20110110
# 1         SO43698  BK-M82S-44  28389      20101229     20110105    20110110
# 2         SO43699  BK-M82S-44  25863      20101229     20110105    20110110
# 3         SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# 4         SO43701  BK-M82S-44  11003      20101229     20110105    20110110
# ...           ...         ...    ...           ...          ...         ...
# 60402     SO75122     FE-6654  15868      20140128     20140204    20140209
# 60403     SO75122     CA-1098  15868      20140128     20140204    20140209
# 60404     SO75123     FE-6654  18759      20140128     20140204    20140209
# 60405     SO75123     ST-1401  18759      20140128     20140204    20140209
# 60406     SO75123     CA-1098  18759      20140128     20140204    20140209
#
#        sls_sales  sls_quantity  sls_price       BDATE     GEN   cst_id  \
# 0         3578.0             1     3578.0  1952-02-19     NaN  21768.0
# 1         3400.0             1     3400.0  1970-06-17  Female  28389.0
# 2         3400.0             1     3400.0  1952-06-01  Female  25863.0
# 3          699.0             1      699.0  1943-11-10    Male  14501.0
# 4         3400.0             1     3400.0  1973-08-14  Female  11003.0
# ...          ...           ...        ...         ...     ...      ...
# 60402       22.0             1       22.0  1976-12-10    Male  15868.0
# 60403        9.0             1        9.0  1976-12-10    Male  15868.0
# 60404       22.0             1       22.0  1983-08-11    Male  18759.0
# 60405      159.0             1      159.0  1983-08-11    Male  18759.0
# 60406        9.0             1        9.0  1983-08-11    Male  18759.0
#
#       cst_firstname cst_lastname cst_marital_status cst_gndr cst_create_date  \
# 0              Cole       Watson                  S        M      2026-01-05
# 1           Rachael     Martinez                  S      NaN      2026-01-25
# 2            Sydney       Wright                  S        F      2026-01-14
# 3             Ruben       Prasad                  M      NaN      2025-10-12
# 4           Christy          Zhu                  S        F      2025-10-06
# ...             ...          ...                ...      ...             ...
# 60402         Caleb          Lal                  S        M      2026-01-04
# 60403         Caleb          Lal                  S        M      2026-01-04
# 60404         Devin     Phillips                  S        M      2026-01-04
# 60405         Devin     Phillips                  S        M      2026-01-04
# 60406         Devin     Phillips                  S        M      2026-01-04
#
#                CNTRY
# 0             Canada
# 1             France
# 2      United States
# 3                USA
# 4          Australia
# ...              ...
# 60402         Canada
# 60403         Canada
# 60404         Canada
# 60405         Canada
# 60406         Canada
#
# [60407 rows x 18 columns]

# %%
sales_df = sales_df.merge(prd_df, how='left', left_on='prd_key', right_on='prd_key', suffixes=('', '_prd'))
sales_df
# Out:
#       sls_ord_num     prd_key    CID  sls_order_dt  sls_ship_dt  sls_due_dt  \
# 0         SO43697  BK-R93R-62  21768      20101229     20110105    20110110
# 1         SO43698  BK-M82S-44  28389      20101229     20110105    20110110
# 2         SO43699  BK-M82S-44  25863      20101229     20110105    20110110
# 3         SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# 4         SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# ...           ...         ...    ...           ...          ...         ...
# 89828     SO75123     FE-6654  18759      20140128     20140204    20140209
# 89829     SO75123     ST-1401  18759      20140128     20140204    20140209
# 89830     SO75123     CA-1098  18759      20140128     20140204    20140209
# 89831     SO75123     CA-1098  18759      20140128     20140204    20140209
# 89832     SO75123     CA-1098  18759      20140128     20140204    20140209
#
#        sls_sales  sls_quantity  sls_price       BDATE  ... prd_id  \
# 0         3578.0             1     3578.0  1952-02-19  ...    310
# 1         3400.0             1     3400.0  1970-06-17  ...    346
# 2         3400.0             1     3400.0  1952-06-01  ...    346
# 3          699.0             1      699.0  1943-11-10  ...    336
# 4          699.0             1      699.0  1943-11-10  ...    337
# ...          ...           ...        ...         ...  ...    ...
# 89828       22.0             1       22.0  1983-08-11  ...    485
# 89829      159.0             1      159.0  1983-08-11  ...    486
# 89830        9.0             1        9.0  1983-08-11  ...    223
# 89831        9.0             1        9.0  1983-08-11  ...    224
# 89832        9.0             1        9.0  1983-08-11  ...    225
#
#                         prd_nm prd_cost prd_line prd_start_dt  prd_end_dt  \
# 0             Road-150 Red- 62   2171.0       R    2011-07-01  2007-12-28
# 1      Mountain-100 Silver- 44   1912.0       M    2011-07-01  2007-12-28
# 2      Mountain-100 Silver- 44   1912.0       M    2011-07-01  2007-12-28
# 3           Road-650 Black- 62    413.0       R    2011-07-01  2007-12-28
# 4           Road-650 Black- 62    487.0       R    2012-07-01  2008-12-27
# ...                        ...      ...      ...          ...         ...
# 89828    Fender Set - Mountain      8.0       M    2013-07-01         NaN
# 89829   All-Purpose Bike Stand     59.0       M    2013-07-01         NaN
# 89830             AWC Logo Cap      6.0       S    2011-07-01  2007-12-28
# 89831             AWC Logo Cap      5.0       S    2012-07-01  2008-12-27
# 89832             AWC Logo Cap      7.0       S    2013-07-01         NaN
#
#           ID          CAT          SUBCAT MAINTENANCE
# 0      BI_RB        Bikes      Road Bikes         Yes
# 1      BI_MB        Bikes  Mountain Bikes         Yes
# 2      BI_MB        Bikes  Mountain Bikes         Yes
# 3      BI_RB        Bikes      Road Bikes         Yes
# 4      BI_RB        Bikes      Road Bikes         Yes
# ...      ...          ...             ...         ...
# 89828  AC_FE  Accessories         Fenders          No
# 89829  AC_BS  Accessories     Bike Stands          No
# 89830  CL_CA     Clothing            Caps          No
# 89831  CL_CA     Clothing            Caps          No
# 89832  CL_CA     Clothing            Caps          No
#
# [89833 rows x 28 columns]

# %%
conn = sqlalchemy.create_engine(
    'postgresql://rod:kT6ccp1WXoUy3CngMOEuqSzS1UYF3YJU@dpg-d0m0hfggjchc739do3dg-a.oregon-postgres.render.com/cloudc'
)

sales_df.to_sql('hardware_sales', conn, if_exists='replace', index=False)
# Out:
# 833

# %%
sales_df= pd.read_sql('SELECT * FROM hardware_sales', conn)
sales_df
# Out:
#       sls_ord_num     prd_key    CID  sls_order_dt  sls_ship_dt  sls_due_dt  \
# 0         SO43697  BK-R93R-62  21768      20101229     20110105    20110110
# 1         SO43698  BK-M82S-44  28389      20101229     20110105    20110110
# 2         SO43699  BK-M82S-44  25863      20101229     20110105    20110110
# 3         SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# 4         SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# ...           ...         ...    ...           ...          ...         ...
# 89828     SO75123     FE-6654  18759      20140128     20140204    20140209
# 89829     SO75123     ST-1401  18759      20140128     20140204    20140209
# 89830     SO75123     CA-1098  18759      20140128     20140204    20140209
# 89831     SO75123     CA-1098  18759      20140128     20140204    20140209
# 89832     SO75123     CA-1098  18759      20140128     20140204    20140209
#
#        sls_sales  sls_quantity  sls_price       BDATE  ... prd_id  \
# 0         3578.0             1     3578.0  1952-02-19  ...    310
# 1         3400.0             1     3400.0  1970-06-17  ...    346
# 2         3400.0             1     3400.0  1952-06-01  ...    346
# 3          699.0             1      699.0  1943-11-10  ...    336
# 4          699.0             1      699.0  1943-11-10  ...    337
# ...          ...           ...        ...         ...  ...    ...
# 89828       22.0             1       22.0  1983-08-11  ...    485
# 89829      159.0             1      159.0  1983-08-11  ...    486
# 89830        9.0             1        9.0  1983-08-11  ...    223
# 89831        9.0             1        9.0  1983-08-11  ...    224
# 89832        9.0             1        9.0  1983-08-11  ...    225
#
#                         prd_nm prd_cost prd_line prd_start_dt  prd_end_dt  \
# 0             Road-150 Red- 62   2171.0       R    2011-07-01  2007-12-28
# 1      Mountain-100 Silver- 44   1912.0       M    2011-07-01  2007-12-28
# 2      Mountain-100 Silver- 44   1912.0       M    2011-07-01  2007-12-28
# 3           Road-650 Black- 62    413.0       R    2011-07-01  2007-12-28
# 4           Road-650 Black- 62    487.0       R    2012-07-01  2008-12-27
# ...                        ...      ...      ...          ...         ...
# 89828    Fender Set - Mountain      8.0       M    2013-07-01        None
# 89829   All-Purpose Bike Stand     59.0       M    2013-07-01        None
# 89830             AWC Logo Cap      6.0       S    2011-07-01  2007-12-28
# 89831             AWC Logo Cap      5.0       S    2012-07-01  2008-12-27
# 89832             AWC Logo Cap      7.0       S    2013-07-01        None
#
#           ID          CAT          SUBCAT MAINTENANCE
# 0      BI_RB        Bikes      Road Bikes         Yes
# 1      BI_MB        Bikes  Mountain Bikes         Yes
# 2      BI_MB        Bikes  Mountain Bikes         Yes
# 3      BI_RB        Bikes      Road Bikes         Yes
# 4      BI_RB        Bikes      Road Bikes         Yes
# ...      ...          ...             ...         ...
# 89828  AC_FE  Accessories         Fenders          No
# 89829  AC_BS  Accessories     Bike Stands          No
# 89830  CL_CA     Clothing            Caps          No
# 89831  CL_CA     Clothing            Caps          No
# 89832  CL_CA     Clothing            Caps          No
#
# [89833 rows x 28 columns]

# %% [markdown]
# # **DATA WAREHOUSE**

# %%
import pandas as pd
import sqlalchemy
import numpy as np
from scipy import stats
from sqlalchemy import create_engine

# %%
conn = sqlalchemy.create_engine(
    'postgresql://rod:kT6ccp1WXoUy3CngMOEuqSzS1UYF3YJU@dpg-d0m0hfggjchc739do3dg-a.oregon-postgres.render.com/cloudc'
)

# Fetch data from the 'hardware_sales' table
data = pd.read_sql('SELECT * FROM hardware_sales', conn)
data.head()  # Display the first 5 rows
# Out:
#   sls_ord_num     prd_key    CID  sls_order_dt  sls_ship_dt  sls_due_dt  \
# 0     SO43697  BK-R93R-62  21768      20101229     20110105    20110110
# 1     SO43698  BK-M82S-44  28389      20101229     20110105    20110110
# 2     SO43699  BK-M82S-44  25863      20101229     20110105    20110110
# 3     SO43700  BK-R50B-62  14501      20101229     20110105    20110110
# 4     SO43700  BK-R50B-62  14501      20101229     20110105    20110110
#
#    sls_sales  sls_quantity  sls_price       BDATE  ... prd_id  \
# 0     3578.0             1     3578.0  1952-02-19  ...    310
# 1     3400.0             1     3400.0  1970-06-17  ...    346
# 2     3400.0             1     3400.0  1952-06-01  ...    346
# 3      699.0             1      699.0  1943-11-10  ...    336
# 4      699.0             1      699.0  1943-11-10  ...    337
#
#                     prd_nm prd_cost prd_line prd_start_dt  prd_end_dt     ID  \
# 0         Road-150 Red- 62   2171.0       R    2011-07-01  2007-12-28  BI_RB
# 1  Mountain-100 Silver- 44   1912.0       M    2011-07-01  2007-12-28  BI_MB
# 2  Mountain-100 Silver- 44   1912.0       M    2011-07-01  2007-12-28  BI_MB
# 3       Road-650 Black- 62    413.0       R    2011-07-01  2007-12-28  BI_RB
# 4       Road-650 Black- 62    487.0       R    2012-07-01  2008-12-27  BI_RB
#
#      CAT          SUBCAT MAINTENANCE
# 0  Bikes      Road Bikes         Yes
# 1  Bikes  Mountain Bikes         Yes
# 2  Bikes  Mountain Bikes         Yes
# 3  Bikes      Road Bikes         Yes
# 4  Bikes      Road Bikes         Yes
#
# [5 rows x 28 columns]

# %% [markdown]
# # **Cleaning**

# %%
def fix_messy_date(val):
    try:
        val_str = str(int(val))
        if len(val_str) == 8:
            return pd.to_datetime(val_str, format='%Y%m%d', errors='coerce').date()
    except:
        return pd.NaT
    return pd.NaT
messy_date_map = {
    'sls_order_dt': 'order_date',
    'sls_ship_dt': 'ship_date',
    'sls_due_dt': 'due_date'
}
for old_col, new_col in messy_date_map.items():
    if old_col in data.columns:
        data[new_col] = data[old_col].apply(fix_messy_date)
        data.drop(old_col, axis=1, inplace=True)
    else:
        print(f"Column '{old_col}' not found — skipping.")
clean_columns_map = {
    'BDATE': 'birth_date',
    'cst_create_date': 'customer_creation_date',
    'prd_start_dt': 'product_start_date',
    'prd_end_dt': 'product_end_date'
}

for old_col, new_col in clean_columns_map.items():
    if old_col in data.columns:
        data[new_col] = pd.to_datetime(data[old_col], errors='coerce').dt.date
        data.drop(old_col, axis=1, inplace=True)
    else:
        print(f"Column '{old_col}' not found — skipping.")

data.head()
# Out:
#   sls_ord_num     prd_key    CID  sls_sales  sls_quantity  sls_price     GEN  \
# 0     SO43697  BK-R93R-62  21768     3578.0             1     3578.0    None
# 1     SO43698  BK-M82S-44  28389     3400.0             1     3400.0  Female
# 2     SO43699  BK-M82S-44  25863     3400.0             1     3400.0  Female
# 3     SO43700  BK-R50B-62  14501      699.0             1      699.0    Male
# 4     SO43700  BK-R50B-62  14501      699.0             1      699.0    Male
#
#     cst_id cst_firstname cst_lastname  ...    CAT          SUBCAT MAINTENANCE  \
# 0  21768.0          Cole       Watson  ...  Bikes      Road Bikes         Yes
# 1  28389.0       Rachael     Martinez  ...  Bikes  Mountain Bikes         Yes
# 2  25863.0        Sydney       Wright  ...  Bikes  Mountain Bikes         Yes
# 3  14501.0         Ruben       Prasad  ...  Bikes      Road Bikes         Yes
# 4  14501.0         Ruben       Prasad  ...  Bikes      Road Bikes         Yes
#
#    order_date   ship_date    due_date  birth_date customer_creation_date  \
# 0  2010-12-29  2011-01-05  2011-01-10  1952-02-19             2026-01-05
# 1  2010-12-29  2011-01-05  2011-01-10  1970-06-17             2026-01-25
# 2  2010-12-29  2011-01-05  2011-01-10  1952-06-01             2026-01-14
# 3  2010-12-29  2011-01-05  2011-01-10  1943-11-10             2025-10-12
# 4  2010-12-29  2011-01-05  2011-01-10  1943-11-10             2025-10-12
#
#   product_start_date product_end_date
# 0         2011-07-01       2007-12-28
# 1         2011-07-01       2007-12-28
# 2         2011-07-01       2007-12-28
# 3         2011-07-01       2007-12-28
# 4         2012-07-01       2008-12-27
#
# [5 rows x 28 columns]

# %%
data['is_active_product'] = data['product_end_date'].isna().astype(int)
data['is_active_product'] = data['product_end_date'].isna().astype(int)

# %%
numeric_cols = ['sls_sales', 'sls_price', 'prd_cost']
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].median())

categorical_cols = ['cst_firstname', 'cst_lastname', 'cst_marital_status']
data[categorical_cols] = data[categorical_cols].fillna('Not Specified')

# %%
data['GEN'] = data['GEN'].str.upper().str.strip()
data['CNTRY'] = data['CNTRY'].str.upper().str.strip()
gender_map = {'Male': 'M', 'Female': 'F', 'm': 'M', 'f': 'F'}
data['cst_gndr'] = data['cst_gndr'].replace(gender_map).fillna('Unknown')

# %%
if data['CID'].equals(data['cst_id'].astype('int64')):
    data.drop('cst_id', axis=1, inplace=True)

# %%
duplicate_count = len(data) - data['sls_ord_num'].nunique()
print(f"{duplicate_count} duplicate order numbers found.")
data = data.drop_duplicates(subset='sls_ord_num', keep='first')
# Out:
# 62174 duplicate order numbers found.

# %%
data['cst_marital_status'].unique()
data['cst_marital_status'] = data['cst_marital_status'].replace({
    'S': 'Single',
    'M': 'Married'
})

# %%
data['full_category'] = data['CAT'] + ' > ' + data['SUBCAT']
#Fix Numeric Outliers
data = data[(np.abs(stats.zscore(data[['sls_quantity', 'sls_price']])) < 3).all(axis=1)]

# %%
data['birth_date'] = pd.to_datetime(data['birth_date'], errors='coerce')
data['customer_age'] = (pd.to_datetime('today') - data['birth_date']).dt.days // 365
data['customer_age'] = data['customer_age'].astype('Int64')
print(data[['order_date', 'ship_date']].dtypes)
# Out:
# order_date    object
# ship_date     object
# dtype: object

# %%
for col in ['order_date', 'ship_date']:
    data[col] = pd.to_datetime(data[col], errors='coerce')
data['order_to_ship_days'] = (data['ship_date'] - data['order_date']).dt.days
data.columns
# Out:
# Index(['sls_ord_num', 'prd_key', 'CID', 'sls_sales', 'sls_quantity',
#        'sls_price', 'GEN', 'cst_firstname', 'cst_lastname',
#        'cst_marital_status', 'cst_gndr', 'CNTRY', 'prd_id', 'prd_nm',
#        'prd_cost', 'prd_line', 'ID', 'CAT', 'SUBCAT', 'MAINTENANCE',
#        'order_date', 'ship_date', 'due_date', 'birth_date',
#        'customer_creation_date', 'product_start_date', 'product_end_date',
#        'is_active_product', 'full_category', 'customer_age',
#        'order_to_ship_days'],
#       dtype='object')

# %%
data.drop(columns=[
    'full_category', 'cst_gndr'
], inplace=True)

# %%
data.isna().sum()
# Out:
# sls_ord_num                   0
# prd_key                       0
# CID                           0
# sls_sales                     0
# sls_quantity                  0
# sls_price                     0
# GEN                        1820
# cst_firstname                 0
# cst_lastname                  0
# cst_marital_status            0
# CNTRY                       332
# prd_id                        0
# prd_nm                        0
# prd_cost                      0
# prd_line                      0
# ID                            0
# CAT                           0
# SUBCAT                        0
# MAINTENANCE                   0
# order_date                    8
# ship_date                     0
# due_date                      0
# birth_date                    9
# customer_creation_date        0
# product_start_date            0
# product_end_date          17088
# is_active_product             0
# customer_age                  9
# order_to_ship_days            8
# dtype: int64

# %%
data = data.dropna()

# %%
data['order_to_ship_days'] = data['order_to_ship_days'].astype('Int64')
for col in ['due_date', 'customer_creation_date', 'product_start_date', 'product_end_date']:
    data[col] = pd.to_datetime(data[col], errors='coerce').dt.date
data['is_active_product'] = data['is_active_product'].astype(bool)
for col in ['order_date', 'ship_date', 'due_date']:
    data[col] = pd.to_datetime(data[col], errors='coerce').dt.date
date_cols = [
    'order_date', 'ship_date', 'due_date',
    'birth_date', 'customer_creation_date',
    'product_start_date', 'product_end_date'
]

for col in date_cols:
    data[col] = pd.to_datetime(data[col], errors='coerce')
for col in date_cols:
    data[f'{col}_month'] = data[col].dt.month_name()

data.head()

data.to_csv('dataset.csv', index=False)

# %%
# !pip install pandas sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (2.0.41)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.11/dist-packages (2.9.10)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
DATABASE_URL = os.getenv('DATABASE_URL')

# Create engine with connection pooling
engine = create_engine(DATABASE_URL)

# %%
from sqlalchemy import create_engine

engine = create_engine(DATABASE_URL)
data.to_sql(
    name='dashboard_data',
    con=engine,
    if_exists='replace',
    index=False,
    chunksize=1000
)

print("Data successfully exported to Render PostgreSQL!")
